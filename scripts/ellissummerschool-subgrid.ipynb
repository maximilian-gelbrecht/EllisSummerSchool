# %% [markdown]
# # Learning subgridscale parametrizations in a atmospheric toy model
#
# You can find this notebook and all additional recourses in this GitHub repo: https://github.com/maximilian-gelbrecht/EllisSummerSchool
#
# ## ELLIS Summer School Project
#
# * Atmospheric dynamics and ocean dynamics exhibit dynamics on many spatial scales: from small scale turbulance to large scale circulation pattern
# * We can't just always increase the resolution to resolve those effects explicilty, espacially for climate models that would be costly
# * Subgridscale parametrizations therefore parametrize the effect the smaller scales have on the larger scales
# * Recent studies showed the potential of ML for these parametrizations (e.g. [Yuval et al 2021](https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/2020gl091363))
# <img src="attachment:3ab37732-7a03-427d-a28b-0f0e864286f0.png" width="600" height="400">
#
#
# ## Lorenz96 System as a conceptual model to test subgridscale parametrizations
#
# * General Circulation Models are computationally very complex and learning
# * Edward Lorenz suggested in 1996 a conceptual model to study the predicitability of the atmosphere, which is also ideally suited for testing subgridscale parametrizations
#
# The two-layer system couples coarse slow ($X$) and small scale fast ($Y$) variables:
#
# $$
# \begin{align}
# \frac{dX_i}{dt} &= (X_{i+1} - X_{i-2}) X_{i-1} - X_i + F - \frac{hc}{b} \sum_{j=1}^J Y_{i,j} \\
# \frac{dY_{i,j}}{dt} &= cb \cdot (Y_{i,j+1} - Y_{i,j-2}) Y_{i,j-1} - c Y_{i,j} + \frac{hc}{b} X_i
# \end{align}
# $$
#
# where:
# - $X_i$ are the slow variables ($i = 1, \ldots, K$), modelling an atmospheric along a latitude ring
# - $Y_{i,j}$ are the fast variables ($i = 1, \ldots, K$; $j = 1, \ldots, J$) along the same latitude ring
# - $h$, $c$, $b$ are scale seperation and coupling parameters
# - $F$ is the forcing parameter, injecting external energy (from other parts of the atmosphere)
# - $(X_{i+1} - X_{i-2}) X_{i-1}$ can be interpreted as a nonlinear advection
# - $-X_i$ as dissipation
#
# ### Parameters
# - $K$: Number of slow variables (grid points)
# - $J$: Number of fast variables per slow variable
# - Total variables: $N = K + K \cdot J$
#
# ### Boundary Conditions
#
# **Slow variables**: Periodic in $i$: $X_i = X_i + K$
#
# **Fast variables**: Periodic in both $i$ and $j$: $Y_{i,j} = Y_{i+K,j}$; $Y_{i,j} = Y_{i,j+J}$
#
# <img src="attachment:0833732e-0599-4f6e-9dd5-ca18c47edb03.png" width="600" height="400">
#
# ## Subgridscale parametrizations in the Lorenz96 model
#
# We can now start to formulate a subgridscale parametrization in the Lorenz96 model:
#
# $$
# \begin{align}
# \frac{dX_i}{dt} &= (X_{i+1} - X_{i-2}) X_{i-1} - X_i + F - P(X) \\
# \end{align}
# $$
#
# in this case, we want to parametrize the effect $P$ of the fast variables $Y$ on $X_i$ purely based on the inputs of $X_i$ that we have avaliable as
#
# $$
# \begin{align}
# P(X) \approx \frac{hc}{b} \sum_{j=1}^J Y_{i,j}
# \end{align}
# $$
#
# ### Different approaches to the parametrizations
#
# In it's simplest form we just try to learn this as
# * One scalar function $P: \mathbb{R} \rightarrow \mathbb{R}$ for $P(X_i) \approx \frac{hc}{b} \sum_{j=1}^J Y_{i,j}$,
#
# but you could also test in the workshop if modelling it with different parametrizations for different grid points:
# * $P_i:\mathbb{R} \rightarrow \mathbb{R}$: $P_i(X_i)$
# * a coupled-vectorized form: $P: \mathbb{R}^K \rightarrow \mathbb{R}^K$
#
# have advantages
#
# ## Training and Testing Setup
#
# * To learn this parametrization you can run the two-layer Lorenz system in the repository and collect training data
# * The parametrization is then tested and evaluated on a two-layer simulation in which the second-layer is regarded as non-observed:
#    * How accuarate is your subgrid scale parametrization in replicating the full system?
#
# ## Online vs Offline Training and Parametrization
#
# As in full Earth system models we have different ways we could train this parametrization:
# <img src="attachment:578dc0e4-40d6-404d-abf8-1037cd068dc9.png" width="600" height="500">
#
# * In an offline training setup: You seperately learn the parametrization $P(X) \approx \frac{hc}{b} \sum_{j=1}^J Y_{i,j}$ and then plug it back in your model
# * In an online training model: You train the parametrization directly within the full hybrid model. In real ESMs this is can be advantagous for stability, and might increase accuracy when the scales are actually not clearly seperated, see e.g. [Gelbrecht, 2023](https://gmd.copernicus.org/articles/16/3123/2023/) or [Kochkov, 2021](https://pnas.org/doi/full/10.1073/pnas.2101784118).
#
# The Lorenz96 system is already trivially differentiable, in contrast to almost all proper ESMs, and is therefore a nice test case for these method.
#
# ## Different ML Architectures
#
# * Test different architectures to fit the subgridscale parametrizations: MLP, CNNs, Polynomials, ...
# * Can you think of other methods and algorithms that might fit?
#
# ## And now, some Code:
#
# Let's integrate the Lorenz96 and plot it. We already have everything pre-defined here in the repository (also in a version that's GPU compatible) and we use the ODE solvers from SciML / `OrdinaryDiffEq` to solve it:

# %%
import Pkg
Pkg.activate("..") 
using EllisSummerSchool, CairoMakie, OrdinaryDiffEq, DiffEqCallbacks, CairoMakie
# Out:
#   Activating project at `~/Nextcloud/EllisSummerSchool`
# Precompiling packages...
#    1092.0 ms  ? DiffEqBase
#    1256.0 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1445.6 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2389.0 ms  ? DiffEqBase → DiffEqBaseDistributionsExt
#    1887.1 ms  ? OrdinaryDiffEqCore
#    4249.2 ms  ? DiffEqCallbacks
#    1854.5 ms  ? OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    6255.6 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
#    1928.5 ms  ? OrdinaryDiffEqHighOrderRK
#    5676.1 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    2716.2 ms  ? OrdinaryDiffEqStabilizedRK
#    5146.6 ms  ? OrdinaryDiffEqExplicitRK
#    4570.7 ms  ? OrdinaryDiffEqSymplecticRK
#   12721.3 ms  ? DiffEqBase → DiffEqBaseUnitfulExt
#    5496.3 ms  ? OrdinaryDiffEqSSPRK
#    4624.8 ms  ? OrdinaryDiffEqFunctionMap
#    4601.8 ms  ? OrdinaryDiffEqLinear
#    8674.9 ms  ? OrdinaryDiffEqLowOrderRK
#    5437.7 ms  ? OrdinaryDiffEqVerner
#    4219.6 ms  ? OrdinaryDiffEqRKN
#    2868.8 ms  ? OrdinaryDiffEqQPRK
#    8310.8 ms  ? OrdinaryDiffEqPRK
#    2294.3 ms  ? OrdinaryDiffEqDifferentiation
#    4531.8 ms  ? OrdinaryDiffEqLowStorageRK
#    1888.5 ms  ? NonlinearSolveQuasiNewton
#   14264.1 ms  ? OrdinaryDiffEqTsit5
#    2815.1 ms  ? NonlinearSolveFirstOrder
#    1775.3 ms  ? OrdinaryDiffEqAdamsBashforthMoulton
#    3651.8 ms  ? SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#    2806.3 ms  ? OrdinaryDiffEqExponentialRK
#   14389.8 ms  ? OrdinaryDiffEqFeagin
#    2341.8 ms  ? NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#    4226.9 ms  ? OrdinaryDiffEqRosenbrock
#   12033.4 ms  ? NonlinearSolveSpectralMethods
#    7547.1 ms  ? OrdinaryDiffEqExtrapolation
#    2023.9 ms  ? NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    6257.1 ms  ? OrdinaryDiffEqNordsieck
#    1915.5 ms  ? NonlinearSolve
#    1349.3 ms  ? OrdinaryDiffEqNonlinearSolve
#    1535.4 ms  ? OrdinaryDiffEqSDIRK
#    2871.9 ms  ? OrdinaryDiffEqPDIRK
#    4241.0 ms  ? OrdinaryDiffEqStabilizedIRK
#    5546.6 ms  ? OrdinaryDiffEqIMEXMultistep
#    5415.2 ms  ? OrdinaryDiffEqBDF
#    1468.8 ms  ? OrdinaryDiffEqDefault
#   13071.9 ms  ? OrdinaryDiffEqFIRK
#    1169.3 ms  ? OrdinaryDiffEq
#    7709.8 ms  ✓ EllisSummerSchool
#   1 dependency successfully precompiled in 67 seconds. 373 already precompiled.
#   47 dependencies failed but may be precompilable after restarting julia
#   47 dependencies had output during precompilation:
# ┌ NonlinearSolveFirstOrder
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqPDIRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqSDIRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqRKN
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseChainRulesCoreExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveSpectralMethods
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqHighOrderRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqFIRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqNonlinearSolve
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqStabilizedIRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqCallbacks
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqRosenbrock
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqFunctionMap
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqCore
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqExponentialRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqBDF
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqFeagin
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqDifferentiation
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqAdamsBashforthMoulton
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqExtrapolation
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolve
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqTsit5
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqDefault
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEq
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqLinear
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqIMEXMultistep
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqLowOrderRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseUnitfulExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqNordsieck
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqPRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveQuasiNewton
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqExplicitRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqSSPRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseDistributionsExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqVerner
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqQPRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseForwardDiffExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqLowStorageRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqSymplecticRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqStabilizedRK
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseSparseArraysExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# Precompiling packages...
#    1038.1 ms  ? DiffEqBase
#    1248.9 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1539.8 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2572.7 ms  ? OrdinaryDiffEqCore
#    3655.0 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    2040.5 ms  ? OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    1949.0 ms  ? NonlinearSolveSpectralMethods
#    1936.6 ms  ? OrdinaryDiffEqExplicitRK
#    3838.7 ms  ? NonlinearSolveQuasiNewton
#    4042.9 ms  ? OrdinaryDiffEqHighOrderRK
#    4489.6 ms  ? OrdinaryDiffEqStabilizedRK
#    4017.6 ms  ? OrdinaryDiffEqSSPRK
#   12562.6 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
#    4818.4 ms  ? OrdinaryDiffEqLowOrderRK
#    4800.8 ms  ? OrdinaryDiffEqFunctionMap
#    3710.4 ms  ? OrdinaryDiffEqTsit5
#    6071.7 ms  ? OrdinaryDiffEqLinear
#    4041.3 ms  ? OrdinaryDiffEqPRK
#    4038.6 ms  ? OrdinaryDiffEqRKN
#    8143.4 ms  ? OrdinaryDiffEqVerner
#    1315.8 ms  ? NonlinearSolveFirstOrder
#    6203.0 ms  ? OrdinaryDiffEqFeagin
#    1889.5 ms  ? SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#    6776.6 ms  ? OrdinaryDiffEqQPRK
#    2842.4 ms  ? OrdinaryDiffEqDifferentiation
#    7267.1 ms  ? OrdinaryDiffEqLowStorageRK
#    3694.3 ms  ? NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    2739.1 ms  ? OrdinaryDiffEqAdamsBashforthMoulton
#    4620.2 ms  ? NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#   24673.6 ms  ? OrdinaryDiffEqSymplecticRK
#    1140.0 ms  ? NonlinearSolve
#    5686.9 ms  ? OrdinaryDiffEqNordsieck
#    1758.2 ms  ? OrdinaryDiffEqNonlinearSolve
#    6496.0 ms  ? OrdinaryDiffEqExponentialRK
#    2242.1 ms  ? OrdinaryDiffEqSDIRK
#    3672.6 ms  ? OrdinaryDiffEqStabilizedIRK
#    4237.7 ms  ? OrdinaryDiffEqFIRK
#    4263.2 ms  ? OrdinaryDiffEqIMEXMultistep
#    4206.8 ms  ? OrdinaryDiffEqPDIRK
#    4067.4 ms  ? OrdinaryDiffEqBDF
#   15271.5 ms  ? OrdinaryDiffEqExtrapolation
#   20499.2 ms  ? OrdinaryDiffEqRosenbrock
#    1527.0 ms  ? OrdinaryDiffEqDefault
# Info Given OrdinaryDiffEq was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1136.3 ms  ? OrdinaryDiffEq
# [ Info: Precompiling OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed]
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed].
# Precompiling packages...
# Info Given DiffEqBase was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#     858.6 ms  ? DiffEqBase
#    1172.7 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# [ Info: Precompiling DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e]
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e].
# Precompiling packages...
#     851.7 ms  ? DiffEqBase
#    1205.6 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# Info Given DiffEqBaseUnitfulExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1083.6 ms  ? DiffEqBase → DiffEqBaseUnitfulExt
# [ Info: Precompiling DiffEqBaseUnitfulExt [aeb06bb4-539b-5a1b-8332-034ed9f8ca66]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBaseUnitfulExt [aeb06bb4-539b-5a1b-8332-034ed9f8ca66].
# Precompiling packages...
#     845.2 ms  ? DiffEqBase
#    1174.1 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# Info Given DiffEqBaseDistributionsExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1305.1 ms  ? DiffEqBase → DiffEqBaseDistributionsExt
# [ Info: Precompiling DiffEqBaseDistributionsExt [24f3332a-0dc5-5d65-94b6-25e75cab9690]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBaseDistributionsExt [24f3332a-0dc5-5d65-94b6-25e75cab9690].
# Precompiling packages...
#     854.0 ms  ? DiffEqBase
#    1579.1 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# Info Given DiffEqBaseChainRulesCoreExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1116.4 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
# [ Info: Precompiling DiffEqBaseChainRulesCoreExt [b00db79b-61e3-50fb-b26f-2d35b2d9e4ed]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBaseChainRulesCoreExt [b00db79b-61e3-50fb-b26f-2d35b2d9e4ed].
# Precompiling packages...
#     856.8 ms  ? DiffEqBase
# Info Given DiffEqBaseSparseArraysExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1184.5 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# [ Info: Precompiling DiffEqBaseSparseArraysExt [4131c53f-b1d6-5635-a7a3-57f6f930b644]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBaseSparseArraysExt [4131c53f-b1d6-5635-a7a3-57f6f930b644].
# Precompiling packages...
#     851.8 ms  ? DiffEqBase
#    1182.3 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# Info Given OrdinaryDiffEqCore was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1278.4 ms  ? OrdinaryDiffEqCore
#    1491.2 ms  ? OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
# [ Info: Precompiling OrdinaryDiffEqCore [bbf590c4-e513-4bbe-9b18-05decba2e5d8]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEqCore [bbf590c4-e513-4bbe-9b18-05decba2e5d8].
# Precompiling packages...
#     875.1 ms  ? DiffEqBase
#    1191.3 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1158.1 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2021.4 ms  ? OrdinaryDiffEqCore
#    1473.0 ms  ? OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#   12189.4 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
# Info Given OrdinaryDiffEqDifferentiation was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    2088.3 ms  ? OrdinaryDiffEqDifferentiation
# [ Info: Precompiling OrdinaryDiffEqDifferentiation [4302a76b-040a-498a-8c04-15b101fed76b]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEqDifferentiation [4302a76b-040a-498a-8c04-15b101fed76b].
# Precompiling packages...
#     852.1 ms  ? DiffEqBase
#    1178.7 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# Info Given DiffEqBaseForwardDiffExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1109.4 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
# [ Info: Precompiling DiffEqBaseForwardDiffExt [1fe0b789-d9ca-5274-abe4-f8a8503e5a20]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBaseForwardDiffExt [1fe0b789-d9ca-5274-abe4-f8a8503e5a20].
# Precompiling packages...
#     871.2 ms  ? DiffEqBase
#    1189.4 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1158.8 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
#    2038.4 ms  ? OrdinaryDiffEqCore
#    3007.3 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    1870.2 ms  ? OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    4856.5 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2827.9 ms  ? NonlinearSolveSpectralMethods
#    1883.3 ms  ? NonlinearSolveFirstOrder
#    1869.6 ms  ? NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    3782.7 ms  ? NonlinearSolveQuasiNewton
#    6583.3 ms  ? SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#    1897.0 ms  ? NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#    1122.4 ms  ? NonlinearSolve
#   12848.1 ms  ? OrdinaryDiffEqDifferentiation
# Info Given OrdinaryDiffEqNonlinearSolve was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1247.1 ms  ? OrdinaryDiffEqNonlinearSolve
# [ Info: Precompiling OrdinaryDiffEqNonlinearSolve [127b3ac7-2247-4354-8eb6-78cf4e7c58e8]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEqNonlinearSolve [127b3ac7-2247-4354-8eb6-78cf4e7c58e8].
# Precompiling packages...
#     845.4 ms  ? DiffEqBase
#    1201.3 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1332.9 ms  ? OrdinaryDiffEqCore
# Info Given OrdinaryDiffEqCoreEnzymeCoreExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1482.3 ms  ? OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
# [ Info: Precompiling OrdinaryDiffEqCoreEnzymeCoreExt [ca1c724a-f4aa-55ef-b8e4-2f05449449ac]
# ┌ Warning: Module OrdinaryDiffEqCore with build ID ffffffff-ffff-ffff-0008-16940a6f4cb8 is missing from the cache.
# │ This may mean OrdinaryDiffEqCore [bbf590c4-e513-4bbe-9b18-05decba2e5d8] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEqCoreEnzymeCoreExt [ca1c724a-f4aa-55ef-b8e4-2f05449449ac].
# Precompiling packages...
#     982.8 ms  ? DiffEqBase
#    1278.7 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
# Info Given NonlinearSolveBaseDiffEqBaseExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1272.5 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
# [ Info: Precompiling NonlinearSolveBaseDiffEqBaseExt [a0bd8381-04c7-5287-82b0-0bf1e59008be]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing NonlinearSolveBaseDiffEqBaseExt [a0bd8381-04c7-5287-82b0-0bf1e59008be].
# Precompiling packages...
#     866.1 ms  ? DiffEqBase
#    1175.5 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1106.7 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    2056.8 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
# Info Given SimpleNonlinearSolveDiffEqBaseExt was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1088.6 ms  ? SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
# [ Info: Precompiling SimpleNonlinearSolveDiffEqBaseExt [904f2055-56f7-5591-b06b-453cba458f4b]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing SimpleNonlinearSolveDiffEqBaseExt [904f2055-56f7-5591-b06b-453cba458f4b].
# Precompiling packages...
#     858.8 ms  ? DiffEqBase
#    1210.6 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1132.0 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2107.2 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    3071.1 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
#    1937.6 ms  ? NonlinearSolveSpectralMethods
#    1886.9 ms  ? NonlinearSolveFirstOrder
#    2809.9 ms  ? SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#    4692.1 ms  ? NonlinearSolveQuasiNewton
#    3703.8 ms  ? NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    1875.3 ms  ? NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
# Info Given NonlinearSolve was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1098.0 ms  ? NonlinearSolve
# [ Info: Precompiling NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec].
# Precompiling packages...
#     855.4 ms  ? DiffEqBase
#    1177.9 ms  ? DiffEqBase → DiffEqBaseSparseArraysExt
#    1104.9 ms  ? DiffEqBase → DiffEqBaseForwardDiffExt
#    2063.4 ms  ? NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    2982.0 ms  ? DiffEqBase → DiffEqBaseChainRulesCoreExt
# Info Given NonlinearSolveFirstOrder was explicitly requested, output will be shown live
# WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1361.9 ms  ? NonlinearSolveFirstOrder
# ...
# │  │ This may mean NonlinearSolveBaseDiffEqBaseExt [a0bd8381-04c7-5287-82b0-0bf1e59008be] does not support precompilation but is imported by a module that does.
# │  └ @ Base loading.jl:2018
# │  ┌ Error: Error during loading of extension NonlinearSolveBaseDiffEqBaseExt of NonlinearSolveBase, use `Base.retry_load_extensions()` to retry.
# │  │   exception =
# │  │    1-element ExceptionStack:
# │  │    Declaring __precompile__(false) is not allowed in files that are being precompiled.
# │  │    Stacktrace:
# │  │      [1] _require(pkg::Base.PkgId, env::Nothing)
# │  │        @ Base ./loading.jl:2022
# │  │      [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │  │        @ Base ./loading.jl:1882
# │  │      [3] #invoke_in_world#3
# │  │        @ ./essentials.jl:926 [inlined]
# │  │      [4] invoke_in_world
# │  │        @ ./essentials.jl:923 [inlined]
# │  │      [5] _require_prelocked
# │  │        @ ./loading.jl:1873 [inlined]
# │  │      [6] _require_prelocked
# │  │        @ ./loading.jl:1872 [inlined]
# │  │      [7] run_extension_callbacks(extid::Base.ExtensionId)
# │  │        @ Base ./loading.jl:1365
# │  │      [8] run_extension_callbacks(pkgid::Base.PkgId)
# │  │        @ Base ./loading.jl:1400
# │  │      [9] run_package_callbacks(modkey::Base.PkgId)
# │  │        @ Base ./loading.jl:1224
# │  │     [10] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │  │        @ Base ./loading.jl:1889
# │  │     [11] #invoke_in_world#3
# │  │        @ ./essentials.jl:926 [inlined]
# │  │     [12] invoke_in_world
# │  │        @ ./essentials.jl:923 [inlined]
# │  │     [13] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │  │        @ Base ./loading.jl:1873
# │  │     [14] macro expansion
# │  │        @ ./loading.jl:1860 [inlined]
# │  │     [15] macro expansion
# │  │        @ ./lock.jl:267 [inlined]
# │  │     [16] __require(into::Module, mod::Symbol)
# │  │        @ Base ./loading.jl:1823
# │  │     [17] #invoke_in_world#3
# │  │        @ ./essentials.jl:926 [inlined]
# │  │     [18] invoke_in_world
# │  │        @ ./essentials.jl:923 [inlined]
# │  │     [19] require(into::Module, mod::Symbol)
# │  │        @ Base ./loading.jl:1816
# │  │     [20] include
# │  │        @ ./Base.jl:495 [inlined]
# │  │     [21] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │  │        @ Base ./loading.jl:2292
# │  │     [22] top-level scope
# │  │        @ stdin:4
# │  │     [23] eval
# │  │        @ ./boot.jl:385 [inlined]
# │  │     [24] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │  │        @ Base ./loading.jl:2146
# │  │     [25] include_string
# │  │        @ ./loading.jl:2156 [inlined]
# │  │     [26] exec_options(opts::Base.JLOptions)
# │  │        @ Base ./client.jl:321
# │  │     [27] _start()
# │  │        @ Base ./client.jl:557
# │  └ @ Base loading.jl:1371
# │  ┌ Warning: Module NonlinearSolveBaseDiffEqBaseExt with build ID fafbfcfd-8630-706d-0008-16fe5b596a54 is missing from the cache.
# │  │ This may mean NonlinearSolveBaseDiffEqBaseExt [a0bd8381-04c7-5287-82b0-0bf1e59008be] does not support precompilation but is imported by a module that does.
# │  └ @ Base loading.jl:2018
# │  ┌ Error: Error during loading of extension NonlinearSolveBaseDiffEqBaseExt of NonlinearSolveBase, use `Base.retry_load_extensions()` to retry.
# │  │   exception =
# │  │    1-element ExceptionStack:
# │  │    Declaring __precompile__(false) is not allowed in files that are being precompiled.
# │  │    Stacktrace:
# │  │      [1] _require(pkg::Base.PkgId, env::Nothing)
# │  │        @ Base ./loading.jl:2022
# │  │      [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │  │        @ Base ./loading.jl:1882
# │  │      [3] #invoke_in_world#3
# │  │        @ ./essentials.jl:926 [inlined]
# │  │      [4] invoke_in_world
# │  │        @ ./essentials.jl:923 [inlined]
# │  │      [5] _require_prelocked
# │  │        @ ./loading.jl:1873 [inlined]
# │  │      [6] _require_prelocked
# │  │        @ ./loading.jl:1872 [inlined]
# │  │      [7] run_extension_callbacks(extid::Base.ExtensionId)
# │  │        @ Base ./loading.jl:1365
# │  │      [8] run_extension_callbacks(pkgid::Base.PkgId)
# │  │        @ Base ./loading.jl:1400
# │  │      [9] run_package_callbacks(modkey::Base.PkgId)
# │  │        @ Base ./loading.jl:1224
# │  │     [10] _tryrequire_from_serialized(modkey::Base.PkgId, path::String, ocachepath::String, sourcepath::String, depmods::Vector{Any})
# │  │        @ Base ./loading.jl:1557
# │  │     [11] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128)
# │  │        @ Base ./loading.jl:1644
# │  │     [12] _require(pkg::Base.PkgId, env::String)
# │  │        @ Base ./loading.jl:2008
# │  │     [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │  │        @ Base ./loading.jl:1882
# │  │     [14] #invoke_in_world#3
# │  │        @ ./essentials.jl:926 [inlined]
# │  │     [15] invoke_in_world
# │  │        @ ./essentials.jl:923 [inlined]
# │  │     [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │  │        @ Base ./loading.jl:1873
# │  │     [17] macro expansion
# │  │        @ ./loading.jl:1860 [inlined]
# │  │     [18] macro expansion
# │  │        @ ./lock.jl:267 [inlined]
# │  │     [19] __require(into::Module, mod::Symbol)
# │  │        @ Base ./loading.jl:1823
# │  │     [20] #invoke_in_world#3
# │  │        @ ./essentials.jl:926 [inlined]
# │  │     [21] invoke_in_world
# │  │        @ ./essentials.jl:923 [inlined]
# │  │     [22] require(into::Module, mod::Symbol)
# │  │        @ Base ./loading.jl:1816
# │  │     [23] include
# │  │        @ ./Base.jl:495 [inlined]
# │  │     [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │  │        @ Base ./loading.jl:2292
# │  │     [25] top-level scope
# │  │        @ stdin:4
# │  │     [26] eval
# │  │        @ ./boot.jl:385 [inlined]
# │  │     [27] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │  │        @ Base ./loading.jl:2146
# │  │     [28] include_string
# │  │        @ ./loading.jl:2156 [inlined]
# │  │     [29] exec_options(opts::Base.JLOptions)
# │  │        @ Base ./client.jl:321
# │  │     [30] _start()
# │  │        @ Base ./client.jl:557
# │  └ @ Base loading.jl:1371
# └
# ┌ NonlinearSolveFirstOrder
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqDifferentiation
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseChainRulesCoreExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolve
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveSpectralMethods
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseForwardDiffExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ OrdinaryDiffEqCore
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DiffEqBase → DiffEqBaseSparseArraysExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveQuasiNewton
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
# │  WARNING: Method definition solve(SciMLBase.EnsembleProblem{T, T2, T3, T4, T5} where T5 where T4 where T3 where T2 where T, Any...) in module SciMLBase at /Users/max/.julia/packages/SciMLBase/wQHrI/src/ensemble/basic_ensemble_solve.jl:356 overwritten in module DiffEqBase at /Users/max/.julia/packages/DiffEqBase/AfBQT/src/solve.jl:1224.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# [ Info: Waiting for another process (pid: 79287) to finish precompiling OrdinaryDiffEqIMEXMultistep [9f002381-b378-40b7-97a6-27a27c83f129]. Pidfile: /Users/max/.julia/compiled/v1.10/OrdinaryDiffEqIMEXMultistep/KRumG_ay2pL.ji.pidfile
# [ Info: Precompiling OrdinaryDiffEqIMEXMultistep [9f002381-b378-40b7-97a6-27a27c83f129]
# ┌ Warning: Module OrdinaryDiffEqCore with build ID ffffffff-ffff-ffff-0008-16940a6f4cb8 is missing from the cache.
# │ This may mean OrdinaryDiffEqCore [bbf590c4-e513-4bbe-9b18-05decba2e5d8] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEqIMEXMultistep [9f002381-b378-40b7-97a6-27a27c83f129].
# [ Info: Precompiling OrdinaryDiffEqExponentialRK [e0540318-69ee-4070-8777-9e2de6de23de]
# ┌ Warning: Module OrdinaryDiffEqCore with build ID ffffffff-ffff-ffff-0008-16940a6f4cb8 is missing from the cache.
# │ This may mean OrdinaryDiffEqCore [bbf590c4-e513-4bbe-9b18-05decba2e5d8] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEqExponentialRK [e0540318-69ee-4070-8777-9e2de6de23de].
# [ Info: Precompiling DiffEqCallbacks [459566f4-90b8-5000-8ac3-15dfb0a30def]
# ┌ Warning: Module DiffEqBase with build ID ffffffff-ffff-ffff-0008-168f6c02e9b5 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing DiffEqCallbacks [459566f4-90b8-5000-8ac3-15dfb0a30def].

# %%
model = TwoLayerLorenz96(K=36, J=10)
p = default_parameters()
u0 = default_initial_condition(model)
dt = 0.005
tspan = (0., 5.)
prob = ODEProblem(model, u0, tspan, p)
sol = solve(prob, Tsit5(), saveat=dt)
sol_data = Array(sol);

# %%
fig = Figure(size=(800, 400))
ax_X = Axis(fig[1,1], title="Slow Variable", xlabel="Grid Point", ylabel="Time")
contourf!(ax_X, sol_data[1:model.K, :]) # heatmap also works 

ax_Y = Axis(fig[1,2], title="Fast Variable", xlabel="Grid Point", ylabel="Time")
contourf!(ax_Y, sol_data[(model.K+1):end, :])
fig

# %% [markdown]
# Or as a polar plot:

# %%
animate_polar_plot(model, sol, rlimits=(-12,12));

# %% [markdown]
# <video width=400 height=400
#        src="lorenz96_animation.mp4"
#        controls>
# </video>

# %% [markdown]
# We can also directly record the subgrid term $\frac{hc}{b} \sum_{j=1}^J Y_{i,j}$ while solving the model with a `SavingCallback`, I already predefined you a helper function `subgrid_save_func` for that:

# %%
#callback type info  = typeof(time), typeof(saved data) 
subgrid_data = SavedValues(typeof(tspan[1]), typeof(u0)) 

cb = SavingCallback(subgrid_save_func, subgrid_data, saveat=dt);

# %%
sol = solve(prob, Tsit5(), saveat=dt, callback=cb);

# %% [markdown]
# You can get the saved subgrid terms then as:

# %%
subgrid_data.saveval
# Out:
# 1001-element Vector{Vector{Float64}}:
#  [0.008119179347418438, 0.03121845684475708, 0.02413091049584991, -0.015069566266029859, 0.038432816559092246, -0.019402862259466563, 0.05819458179596865, 0.039004028756440046, 0.06797752563951047, 0.01779814963641526  …  -0.03468581951125474, 0.022682728146236848, -0.001501659293376473, -0.009244054323036412, -0.003591879099008882, -0.026190266175210662, -0.000847585224190186, 0.013457410396373722, 0.06487282270281404, -0.05022751809150924]
#  [0.009043272025739745, 0.04300500493792421, 0.04554726866779154, 0.011794135788539677, 0.05927588437612297, -0.005111724169139692, 0.05694253515897685, 0.026602950240368163, 0.04511536237255998, -0.00551087426611978  …  -0.010540518007022517, 0.04727463567230161, 0.02090665983664098, 0.004633858016319319, -0.001844721806862141, -0.03552503129938641, -0.020321342760011588, -0.009973536373007628, 0.04209897356101788, -0.057851429234896994]
#  [0.012828169183754137, 0.05705702971157765, 0.06877321150556256, 0.04014873073766515, 0.08184495047853495, 0.011294879530184723, 0.05858334102789364, 0.01775092412926215, 0.026383053043549192, -0.024688311935795168  …  0.015258214537537158, 0.07348855614921489, 0.045011809367763056, 0.020669951678216763, 0.0026583826561631806, -0.041439066813180374, -0.0357851634464824, -0.02921413965954503, 0.02340185606508497, -0.06220133783687748]
#  [0.019322893292221796, 0.07324599877559448, 0.09370355698607416, 0.06990575952758896, 0.10603980800440826, 0.029690901495213133, 0.06295123188897916, 0.012250743370438091, 0.011562738608008695, -0.039938733191257826  …  0.042613220871228846, 0.10122572248315657, 0.0707095142818236, 0.03873453684774252, 0.009764132024894817, -0.044124345890990735, -0.047460656043064264, -0.04448079120268852, 0.008584963251707243, -0.06343927728680325]
#  [0.02838232035169072, 0.09144964801409408, 0.12023778464955347, 0.1009806115283704, 0.13176482941741854, 0.04995697762000195, 0.06988977654515874, 0.00991579737207371, 0.00044661772883108474, -0.05145939466447359  …  0.07143213135627946, 0.13039186195591373, 0.09790078280594233, 0.05870490720744572, 0.019326801798625243, -0.04376265065162308, -0.055557561130982605, -0.05598080836904874, -0.002542163570021242, -0.06172238215674731]
#  [0.03986711956681054, 0.11155170956181187, 0.14827989864790223, 0.13329236160913704, 0.15892873287568487, 0.07197999619933794, 0.0792512622044241, 0.01056942497026281, -0.007163412015155512, -0.05944027145433628  …  0.10162714423122725, 0.16089698284343976, 0.12649156003732062, 0.08046491646032448, 0.031207861312273533, -0.04052616435010352, -0.06027443273244357, -0.06391266880741334, -0.01016382317864814, -0.05720273651894576]
#  [0.05364380900173925, 0.13344172308955465, 0.17773834240984315, 0.16676366701032524, 0.1874444226037432, 0.09565276361186369, 0.09089618584124028, 0.014044405613658325, -0.011455994953525873, -0.06406396329756311  …  0.13311487233144537, 0.1926552234559663, 0.15639246623071773, 0.10390464439352351, 0.0452756784556306, -0.03457791968474091, -0.061799181518369, -0.06846610286336387, -0.014457921862276128, -0.050027119383187255]
#  [0.0695845509734157, 0.15701458881208147, 0.20852571487010152, 0.20132047321567237, 0.21722861758553044, 0.12087339323715669, 0.10469236251376515, 0.0201820281444779, -0.012611010673495546, -0.06550594436124182  …  0.16581597149201605, 0.22558451681260244, 0.1875182967866446, 0.12891977199776278, 0.06140490506118952, -0.026072650810901047, -0.060310111394820926, -0.06982259236800409, -0.015596026940941293, -0.04033696526303065]
#  [0.08756704700343244, 0.18217037975965295, 0.2405586458274304, 0.2368918861424679, 0.24820169530649505, 0.14754505823225178, 0.12051456601674537, 0.028831712433582395, -0.010799873198837209, -0.06393469628028206  …  0.19965498272670307, 0.259606450041889, 0.21978781786355983, 0.15541132722684387, 0.07947622177875145, -0.015157142001257978, -0.055976343454001494, -0.068155597449704, -0.013743424099490361, -0.028268381246499615]
#  [0.10747449547995805, 0.20881415204882414, 0.27375765733588237, 0.27341004666662194, 0.2802875411984552, 0.1755757321782578, 0.13824412101518507, 0.03985060478457123, -0.006185846184441587, -0.059511767424688014  …  0.23456016935855778, 0.2946461225058749, 0.2531235583390225, 0.18328540692243075, 0.09937605732178086, -0.0019705869887405468, -0.04895828500051887, -0.06363073907261203, -0.009059075584294893, -0.013952068975013561]
#  [0.12919553281519128, 0.23685576008078335, 0.3080470262391383, 0.3108100112076799, 0.31341340385385597, 0.20487794049351454, 0.1577685209633575, 0.05310319414360311, 0.0010756580328288245, -0.05239183043912806  …  0.2704633624939303, 0.33063200913357776, 0.28745161236257794, 0.21245291165321753, 0.12099632374025203, 0.013355066667475463, -0.03940806997343259, -0.05640597608142933, -0.001695583486909926, 0.0024867433590389644]
#  [0.15262383447436945, 0.2662094059685164, 0.34335440715292626, 0.349029401671073, 0.3475095196248605, 0.2353682297442662, 0.17898065993549891, 0.06846047646739431, 0.010836290108338276, -0.04272317885570333  …  0.30729955423639327, 0.36749561758073673, 0.3227011921183823, 0.24282897836422013, 0.14423381230077822, 0.030694321244350373, -0.027470512417041903, -0.04663227024676586, 0.00820045598904744, 0.02092804034387776]
#  [0.17765806184921248, 0.2967935745093744, 0.3796107785777055, 0.388008355246808, 0.3825090585277128, 0.26696708984287126, 0.20177871844800033, 0.08579983197099922, 0.022954649706992757, -0.03064779489447691  …  0.3450068388230882, 0.40517143868562944, 0.35880456243291536, 0.27433289701525887, 0.168990104943261, 0.049928012820726994, -0.013283247077298044, -0.03445367980561728, 0.020488406664772515, 0.041256987146812515]
#  ⋮
#  [0.7461895946655739, 1.8421764392912885, 3.6970640704188424, 2.0026158040408637, 1.2682462290537033, 0.7347718007060021, 2.1133528882579884, 3.013660519899587, -1.552043144779052, 0.14516705748232528  …  -1.112837305148522, 2.01643834090881, -0.13393295472761182, -1.2301776338537214, 0.586676345856697, 1.2733331296269532, 1.5982136347535505, 0.8413628521458071, 1.2731487698929007, -0.9376670613326509]
#  [0.782495610227371, 1.9349383294047804, 3.4879568067776017, 1.8728005105263505, 1.2969711727174302, 0.6909026026052778, 2.1322511587158566, 2.972931869884493, -1.6048622792855105, 0.16886121188155517  …  -1.1606271273045339, 2.4642803650050724, -0.21959646680621298, -1.1242344135411964, 0.4353439893619878, 1.2690947642024795, 1.659938484457987, 0.805051133868937, 1.2811065867615945, -0.8840938672774231]
#  [0.8174784728755674, 2.0324392416094597, 3.2892750933163435, 1.758075084981399, 1.3571811603698967, 0.685017253791135, 2.1369919227964793, 2.874690188993168, -1.6504567027906605, 0.19592711178243727  …  -1.1527170316522386, 2.827530472177346, -0.3027491890810207, -1.0194317113604545, 0.27322926749714793, 1.340025103130237, 1.7921333160161788, 0.7701710438543231, 1.2943331592114322, -0.8272266175236471]
#  [0.8508356864254998, 2.124425995024448, 2.890576136478405, 1.6555122621817797, 1.426211205784491, 0.7154622508389535, 2.140235306504686, 2.6943983622523167, -1.687611519771804, 0.22668272110419635  …  -1.081193631539365, 3.1079767858972147, -0.38391134739425276, -0.9227461513209351, 0.12121944908316648, 1.3732359268890384, 1.9937581709822132, 0.7365936605835849, 1.3160882129216205, -0.7674282439309692]
#  [0.8822259017983276, 2.199114635960728, 2.1648987666098662, 1.560481727934962, 1.4828529724093558, 0.7737776730050203, 2.1579421253684568, 2.4328678494059046, -1.7147975923464762, 0.26127475400863115  …  -0.9586053399750969, 3.3023592613071218, -0.4639721445943681, -0.839001769224901, -0.01182474129078498, 1.3004563268879135, 2.250564128115635, 0.703743878817722, 1.3490151006456592, -0.705085742755057]
#  [0.9112699227959812, 2.2477542596139592, 1.426431325457339, 1.4715440882007789, 1.510987737359558, 0.8481815516717259, 2.1973564607413407, 2.132982313739975, -1.730055570518229, 0.29976030000630016  …  -0.8151768869691792, 3.382369728633334, -0.5434070667330656, -0.7705640536139837, -0.12558531605041057, 1.1357580224186299, 2.536660342738741, 0.6707452245865231, 1.3942534599760885, -0.640597801789528]
#  [0.9375639340526938, 2.2646789092261335, 1.2697250692440702, 1.3910941863404045, 1.5010799641603916, 0.9270763134815293, 2.251254863720896, 1.8588582235511872, -1.730884653947901, 0.3421525595910219  …  -0.6886572529766088, 3.3011670920014415, -0.6214186550805236, -0.717574953028667, -0.22380425521025737, 0.958147639467349, 2.8199186525652626, 0.636645445001154, 1.4509157382359938, -0.5743595201510003]
#  [0.9607181662644115, 2.239395826049471, 1.892158351498794, 1.3201074389111085, 1.4503486902839522, 1.0017782005594864, 2.3019617819422327, 1.6566487929810738, -1.7141700043700543, 0.388436528614779  …  -0.6138791801706911, 3.0517396473775933, -0.6952983567697769, -0.6785634911071621, -0.30994101653538814, 0.8480451016486173, 3.06847900481689, 0.6006706950744947, 1.5161404207774172, -0.5067448001142805]
#  [0.9804346424321239, 2.160903512921232, 2.8631576943276325, 1.2549917246866196, 1.3622101435841323, 1.0694202546524834, 2.3292232282484893, 1.5411122531612091, -1.6762127035180276, 0.43856370827452684  …  -0.6161077442692627, 2.7399406362885337, -0.7606933033295287, -0.6511347576934162, -0.38426064833174767, 0.8295221214650952, 3.255108896470029, 0.5624396888252347, 1.5856969573148907, -0.4380885857122759]
#  [0.9966279794245206, 2.0551840763309848, 3.66854953964893, 1.1897801466547524, 1.2451914219004412, 1.134658488181936, 2.314861785234938, 1.4992596325166034, -1.6129399954647663, 0.492436638151291  …  -0.703615358920681, 2.5263874433514513, -0.8130985152385698, -0.6325639817421829, -0.4436643507767978, 0.863331153948834, 3.3609763058306634, 0.522100258441612, 1.6549072432422631, -0.36867020348669893]
#  [1.0095627618520873, 2.015673458906116, 4.055650953991352, 1.1194974569010685, 1.1111021967295027, 1.206733703232782, 2.244837548969821, 1.502797260700873, -1.5204282962286348, 0.5498909431263201  …  -0.8632349434946711, 2.4499504158289254, -0.849550561657183, -0.6202252794276232, -0.48595722769427885, 0.8930548369246666, 3.3815536347469712, 0.48033722332124595, 1.719590467572223, -0.29869942416639494]
#  [1.0199282495882072, 2.151449512584983, 4.049531753551337, 1.0431030754996768, 0.9726863893900506, 1.292332521004905, 2.114815919033751, 1.5223613276089587, -1.3958194180814765, 0.6106809323438748  …  -1.0688122767187442, 2.4246274471091933, -0.8692501812896017, -0.6118302656775962, -0.515793083034015, 0.8975216569096587, 3.3339736799704762, 0.43825405510678184, 1.776716397423332, -0.228306946570333]

# %% [markdown]
# ## A suggested roadmap
#
# 1. Make a Slack group to coordinate everything
# 1. Generate training data
# 2. What architectures and setups do you want to use?
# 3. Implement the models you want to use
# 4. Train and test the models individually
# 5. Compare all of your approaches against each other
#
# ## Now, for ML
#
# Do you already have some experience with ML in Julia? If so, great, just go ahead and start working. In the other notebook there are also some details about Neural ODEs that might still be helpful.
#
# For everyone who needs an introduction to ML in Julia, I collected some recourses in the other notebook.
